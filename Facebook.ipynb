# %%
import pandas as pd
df = pd.read_csv("dataset_Facebook.csv",sep=",")

# %%
df
# Out:
#      pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 0            139441     2         2         12            4         3     0
# 1            139441     3         2         12            3        10     0
# 2            139441     2         3         12            3         3     0
# 3            139441     2         2         12            2        10     1
# 4            139441     2         2         12            2         3     0
# ..              ...   ...       ...        ...          ...       ...   ...
# 367           85093     2         3          1            7        10     0
# 368           85093     2         3          1            7         2     0
# 369           81370     2         2          1            5         8     0
# 370           81370     2         1          1            5         2     0
# 371           81370     2         3          1            4        11     0
#
# ...

# %%
df.describe()
# Out:
#        pagetotallikes        type    category   postmonth  postweekday  \
# count      372.000000  372.000000  372.000000  372.000000   372.000000
# mean    120482.123656    2.040323    1.876344    6.836022     4.212366
# std      17825.647677    0.423040    0.884597    3.756395     2.036211
# min      81370.000000    1.000000    1.000000    1.000000     1.000000
# 25%     107907.000000    2.000000    1.000000    4.000000     2.000000
# 50%     124940.000000    2.000000    2.000000    6.000000     4.000000
# 75%     137059.000000    2.000000    3.000000   11.000000     6.000000
# max     139441.000000    4.000000    3.000000   12.000000     7.000000
#
#          posthour        paid  lifetimeposttotalreach  \
# count  372.000000  372.000000              372.000000
# mean     7.876344    0.255376            13278.422043
# std      4.432273    0.436660            21395.541417
# min      1.000000    0.000000              238.000000
# ...

# %%
df.shape
# Out:
# (372, 19)

# %%
df1=df[['pagetotallikes', 'type', 'category']].loc[0:15]

# %%
df2=df[['pagetotallikes', 'type', 'category']].loc[16:30]

# %%
df3=df[['pagetotallikes', 'type', 'category']].loc[31:50]

# %%
df1
# Out:
#     pagetotallikes  type  category
# 0           139441     2         2
# 1           139441     3         2
# 2           139441     2         3
# 3           139441     2         2
# 4           139441     2         2
# 5           139441     3         2
# 6           139441     2         3
# 7           139441     2         3
# 8           139441     3         2
# 9           139441     2         3
# 10          139441     3         2
# 11          139441     2         2
# 12          139441     2         2
# 13          139441     2         2
# 14          138414     2         2
# 15          138414     3         2

# %%
df2
# Out:
#     pagetotallikes  type  category
# 16          138414     2         3
# 17          138414     2         1
# 18          138414     3         3
# 19          138414     2         3
# 20          138414     2         2
# 21          138414     2         1
# 22          138414     1         1
# 23          138414     2         3
# 24          138414     3         2
# 25          138458     3         2
# 26          138458     3         2
# 27          138458     2         3
# 28          138895     2         2
# 29          138895     4         1
# 30          138895     2         2

# %%
df3
# Out:
#     pagetotallikes  type  category
# 31          138895     2         2
# 32          138895     2         3
# 33          138895     2         3
# 34          138895     2         1
# 35          138895     2         2
# 36          138895     2         3
# 37          138895     2         1
# 38          138895     3         2
# 39          138895     2         1
# 40          138895     3         2
# 41          138895     1         1
# 42          138353     2         1
# 43          138353     1         1
# 44          138353     2         1
# 45          138353     1         1
# 46          138353     3         1
# 47          138353     1         1
# 48          138353     2         1
# 49          138353     1         1
# 50          138353     2         2

# %%
merging=pd.concat([df1,df2,df3])

# %%
merging
# Out:
#     pagetotallikes  type  category
# 0           139441     2         2
# 1           139441     3         2
# 2           139441     2         3
# 3           139441     2         2
# 4           139441     2         2
# 5           139441     3         2
# 6           139441     2         3
# 7           139441     2         3
# 8           139441     3         2
# 9           139441     2         3
# 10          139441     3         2
# 11          139441     2         2
# 12          139441     2         2
# 13          139441     2         2
# 14          138414     2         2
# 15          138414     3         2
# 16          138414     2         3
# 17          138414     2         1
# 18          138414     3         3
# 19          138414     2         3
# 20          138414     2         2
# 21          138414     2         1
# 22          138414     1         1
# 23          138414     2         3
# 24          138414     3         2
# 25          138458     3         2
# ...

# %%
sort_values=df.sort_values('pagetotallikes',ascending=False)

# %%
sort_values
# Out:
#      pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 0            139441     2         2         12            4         3     0
# 8            139441     3         2         12            7         3     0
# 1            139441     3         2         12            3        10     0
# 13           139441     2         2         12            5         3     0
# 12           139441     2         2         12            5        10     0
# ..              ...   ...       ...        ...          ...       ...   ...
# 367           85093     2         3          1            7        10     0
# 368           85093     2         3          1            7         2     0
# 369           81370     2         2          1            5         8     0
# 370           81370     2         1          1            5         2     0
# 371           81370     2         3          1            4        11     0
#
# ...

# %%
shape=df.shape

# %%
shape
# Out:
# (372, 19)

# %%
df.transpose()
# Out:
#                                                        0       1       2    \
# pagetotallikes                                      139441  139441  139441
# type                                                     2       3       2
# category                                                 2       2       3
# postmonth                                               12      12      12
# postweekday                                              4       3       3
# posthour                                                 3      10       3
# paid                                                     0       0       0
# lifetimeposttotalreach                                2752   10460    2413
# lifetimeposttotalimpressions                          5091   19057    4373
# lifetimeengagedusers                                   178    1457     177
# lifetimepostconsumers                                  109    1361     113
# ...

# %%
pivot_table=pd.pivot_table(df,index=['type','category'], values='like')
pivot_table
# Out:
#                      like
# type category
# 1    1          75.650000
#      2          32.000000
#      3          68.000000
# 2    1         112.354167
#      2         217.339623
#      3         201.258333
# 3    1         136.333333
#      2         218.454545
#      3         151.500000
# 4    1         189.000000
