# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('heartdisease.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num
# 0  0    6    0
# 1  3    3    2
# 2  2    7    1
# 3  0    3    0
# 4  0    3    0

# %%
sns.barplot(x='sex',y='thalach',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='thalach'>

# %%
sns.scatterplot(x='age',y='thalach',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %%
sns.lineplot(x='sex',y='thalach',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='thalach'>

# %%
plt.figure(figsize=(14,14))
sns.pairplot(df,hue='sex',palette='Reds')

# %%
sns.displot(df['thalach'])

# %%
plt.scatter(df['thalach'],df['age'])
plt.show()

# %%
sex_df = pd.DataFrame(df['sex'].value_counts())

# %%
sex_df
# Out:
#    sex
# 1  206
# 0   97

# %%
plt.pie(sex_df['sex'],labels=sex_df.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f85f48af820>,
#   <matplotlib.patches.Wedge at 0x7f85f48afd00>],
#  [Text(-0.5890242258008583, 0.9290050922463772, '1'),
#   Text(0.5890242258008579, -0.9290050922463774, '0')])

# %%
plt.bar(sex_df.index,sex_df['sex'])
plt.show()
